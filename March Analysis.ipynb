# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 2023 March Madness Stats
#
# ### First Four

# %%
first_four = pd.read_csv('first_four.csv')

# %%
first_four = first_four[['Rk', 'Team', 'Seed', 'Date', 'PTS', 'Opp', 'Opp Seed',
       'Result', 'Round', 'Region', 'FG', 'FGA', 'FG%', '2P', '2PA',
       '2P%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%']]

# %% [markdown]
# ### Round One

# %%
round_one = pd.read_csv('round_of_64.csv')

# %%
round_one = round_one[['Rk', 'Team', 'Seed', 'Date', 'PTS', 'Opp', 'Opp Seed',
       'Result', 'Round', 'Region', 'FG', 'FGA', 'FG%', '2P', '2PA',
       '2P%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%']]

# %%
round_one
# Out:
#     Rk               Team  Seed             Date  PTS  \
# 0    1            Alabama     1  2023-03-16 NCAA   96
# 1    2             Kansas     1  2023-03-16 NCAA   96
# 2    3        Connecticut     4  2023-03-17 NCAA   87
# 3    4               UCLA     2  2023-03-16 NCAA   86
# 4    5             Auburn     9  2023-03-16 NCAA   83
# ..  ..                ...   ...              ...  ...
# 59  60      UNC Asheville    15  2023-03-16 NCAA   53
# 60  61  Northern Kentucky    16  2023-03-16 NCAA   52
# 61  62                VCU    12  2023-03-17 NCAA   51
# 62  63       Oral Roberts    12  2023-03-16 NCAA   51
# 63  64         Iowa State     6  2023-03-17 NCAA   41
#
#                          Opp  Opp Seed   Result      Round   Region  ...  \
# 0   Texas A&M–Corpus Christi        16  W 96-75  Rnd of 64    South  ...
# 1                     Howard        16  W 96-68  Rnd of 64     West  ...
# 2                       Iona        13  W 87-63  Rnd of 64     West  ...
# ...

# %% [markdown]
# ### Round Two

# %%
round_two = pd.read_csv('round_of_32.csv')

# %%
round_two = round_two[['Rk', 'Team', 'Seed', 'Date', 'PTS', 'Opp', 'Opp Seed',
       'Result', 'Round', 'Region', 'FG', 'FGA', 'FG%', '2P', '2PA',
       '2P%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%']]

# %%
round_two
# Out:
#     Rk              Team  Seed             Date  PTS               Opp  \
# 0    1        Miami (FL)     5  2023-03-19 NCAA   85           Indiana
# 1    2         Creighton     6  2023-03-19 NCAA   85            Baylor
# 2    3           Gonzaga     3  2023-03-19 NCAA   84               TCU
# 3    4            Xavier     3  2023-03-19 NCAA   84        Pittsburgh
# 4    5               TCU     6  2023-03-19 NCAA   81           Gonzaga
# 5    6           Houston     1  2023-03-18 NCAA   81            Auburn
# 6    7  Florida Atlantic     9  2023-03-19 NCAA   78               FDU
# 7    8         Princeton    15  2023-03-18 NCAA   78          Missouri
# 8    9            Baylor     3  2023-03-19 NCAA   76         Creighton
# 9   10      Kansas State     3  2023-03-19 NCAA   75          Kentucky
# 10  11   San Diego State     5  2023-03-18 NCAA   75            Furman
# 11  12        Pittsburgh    11  2023-03-19 NCAA   73            Xavier
# ...

# %% [markdown]
# ### Sweet 16

# %%
sweet_16 = pd.read_csv('sweet_16.csv')

# %%
sweet_16 = sweet_16[['Rk', 'Team', 'Seed', 'Date', 'PTS', 'Opp', 'Opp Seed',
       'Result', 'Round', 'Region', 'FG', 'FGA', 'FG%', '2P', '2PA',
       '2P%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%']]

# %%
sweet_16
# Out:
#     Rk              Team  Seed             Date  PTS               Opp  \
# 0    1      Kansas State     3  2023-03-23 NCAA   98    Michigan State
# 1    2    Michigan State     7  2023-03-23 NCAA   93      Kansas State
# 2    3        Miami (FL)     5  2023-03-24 NCAA   89           Houston
# 3    4       Connecticut     4  2023-03-23 NCAA   88          Arkansas
# 4    5         Creighton     6  2023-03-24 NCAA   86         Princeton
# 5    6             Texas     2  2023-03-24 NCAA   83            Xavier
# 6    7           Gonzaga     3  2023-03-23 NCAA   79              UCLA
# 7    8              UCLA     2  2023-03-23 NCAA   76           Gonzaga
# 8    9           Houston     1  2023-03-24 NCAA   75        Miami (FL)
# 9   10         Princeton    15  2023-03-24 NCAA   75         Creighton
# 10  11            Xavier     3  2023-03-24 NCAA   71             Texas
# 11  12   San Diego State     5  2023-03-24 NCAA   71           Alabama
# ...

# %% [markdown]
# ### Elite 8

# %%
elite_8 = pd.read_csv('elite_8.csv')

# %%
elite_8 = elite_8[['Rk', 'Team', 'Seed', 'Date', 'PTS', 'Opp', 'Opp Seed',
       'Result', 'Round', 'Region', 'FG', 'FGA', 'FG%', '2P', '2PA',
       '2P%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%']]

# %%
elite_8
# Out:
#    Rk              Team  Seed             Date  PTS               Opp  \
# 0   1        Miami (FL)     5  2023-03-26 NCAA   88             Texas
# 1   2       Connecticut     4  2023-03-25 NCAA   82           Gonzaga
# 2   3             Texas     2  2023-03-26 NCAA   81        Miami (FL)
# 3   4  Florida Atlantic     9  2023-03-25 NCAA   79      Kansas State
# 4   5      Kansas State     3  2023-03-25 NCAA   76  Florida Atlantic
# 5   6   San Diego State     5  2023-03-26 NCAA   57         Creighton
# 6   7         Creighton     6  2023-03-26 NCAA   56   San Diego State
# 7   8           Gonzaga     3  2023-03-25 NCAA   54       Connecticut
#
#    Opp Seed   Result     Round   Region  ...    FG%  2P  2PA    2P%  3P  3PA  \
# 0         2  W 88-81  Rnd of 8  Midwest  ...  0.592  27   41  0.659   2    8
# 1         3  W 82-54  Rnd of 8     West  ...  0.417  19   41  0.463  11   31
# 2         5  L 81-88  Rnd of 8  Midwest  ...  0.500  20   35  0.571  10   25
# ...

# %% [markdown]
# ### Final Four and Championship Game Stat

# %%
final_four = pd.read_csv('final_four.csv')

# %%
final_four = final_four[['Rk', 'Team', 'Seed', 'Date', 'PTS', 'Opp', 'Opp Seed',
       'Result', 'Round', 'Region', 'FG', 'FGA', 'FG%', '2P', '2PA',
       '2P%', '3P', '3PA', '3P%', 'FT', 'FTA', 'FT%']]

# %%
final_four
# Out:
#    Rk              Team  Seed             Date  PTS               Opp  \
# 0   1       Connecticut     4  2023-04-03 NCAA   76   San Diego State
# 1   2   San Diego State     5  2023-04-01 NCAA   72  Florida Atlantic
# 2   3       Connecticut     4  2023-04-01 NCAA   72        Miami (FL)
# 3   4  Florida Atlantic     9  2023-04-01 NCAA   71   San Diego State
# 4   5   San Diego State     5  2023-04-03 NCAA   59       Connecticut
# 5   6        Miami (FL)     5  2023-04-01 NCAA   59       Connecticut
#
#    Opp Seed   Result           Round   Region  ...    FG%  2P  2PA    2P%  3P  \
# 0         5  W 76-59  National Final     West  ...  0.434  17   36  0.472   6
# 1         9  W 72-71   National Semi    South  ...  0.439  16   39  0.410   9
# 2         5  W 72-59   National Semi     West  ...  0.491  19   31  0.613   9
# 3         5  L 71-72   National Semi     East  ...  0.442  14   30  0.467   9
# 4         4  L 59-76  National Final    South  ...  0.322  13   36  0.361   6
# ...
